# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.read_edgelist('random1.edgelist')
degrees = dict(G.degree())
degree_values = sorted(set(degrees.values()))
in_hist = [list(degrees.values()).count(x) for x in degree_values]
plt.plot(degree_values, in_hist, 'o')
plt.xlabel('Degree')
plt.ylabel('Fraction of Nodes')
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
G = nx.read_edgelist('random2.edgelist')
degrees = dict(G.degree())
degree_values = sorted(set(degrees.values()))
in_hist = [list(degrees.values()).count(x) for x in degree_values]
plt.plot(degree_values, in_hist, 'o')
plt.xlabel('Degree')
plt.ylabel('Fraction of Nodes')
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
G = nx.read_edgelist('random3.edgelist')
degrees = dict(G.degree())
degree_values = sorted(set(degrees.values()))
in_hist = [list(degrees.values()).count(x) for x in degree_values]
plt.plot(degree_values, in_hist, 'o')
plt.xlabel('Degree')
plt.ylabel('Fraction of Nodes')
plt.xscale('log')
plt.yscale('log')
plt.show()
# Doesn't follow power law distrubution
# Small world graph with high probability of rewiring

# %%
G = nx.read_edgelist('random4.edgelist')
degrees = dict(G.degree())
degree_values = sorted(set(degrees.values()))
in_hist = [list(degrees.values()).count(x) for x in degree_values]
plt.plot(degree_values, in_hist, 'o')
plt.xlabel('Degree')
plt.ylabel('Fraction of Nodes')
plt.xscale('log')
plt.yscale('log')
print(nx.average_shortest_path_length(G))
print(nx.average_clustering(G))
plt.show()
# even higher clustering coeficient and longer shoertest path
